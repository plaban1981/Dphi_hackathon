# %% [markdown]
# <a href="https://colab.research.google.com/github/plaban1981/Dphi_hackathon/blob/main/Gender_Determination_DL_bootcamp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Problem Statement
# The anthropometric analysis of the human face is an essential study for performing craniofacial plastic and reconstructive surgeries. Facial anthropometrics are affected by various factors such as age, gender, ethnicity, socioeconomic status, environment, and region.
#
#
#
# Plastic surgeons who undertake the repair and reconstruction of facial deformities find the anatomical dimensions of the facial structures useful for their surgeries. These dimensions are a result of the Physical or Facial appearance of an individual. Along with factors like culture, personality, ethnic background, age; eye appearance and symmetry contributes majorly to the facial appearance or aesthetics.
#
#
#
# ## Objective
# Build a model to scan the image of an eye of a patient and find if the gender of the patient is male or female.

# %% [markdown]
# ## Evaluation
# Submissions are evaluated using **Accuracy Score** and the score displayed on the leaderboard is 100 * Accuracy Score.

# %% [markdown]
# ## Problem Solution

# %% [markdown]
# ## Download the images

# %%
from google_drive_downloader import GoogleDriveDownloader as gdd

gdd.download_file_from_google_drive(file_id='1f7uslI-ZHidriQFZR966_aILjlkgDN76',
dest_path='content/eye_gender_data.zip',
unzip=True)
# Out:
# Downloading 1f7uslI-ZHidriQFZR966_aILjlkgDN76 into content/eye_gender_data.zip... Done.
# Unzipping...Done.

# %% [markdown]
# ## Loading Libraries

# %%
# !pip install ipyplot
# Out:
# Collecting ipyplot
#   Downloading ipyplot-1.1.0-py3-none-any.whl (13 kB)
# Collecting shortuuid
#   Downloading shortuuid-1.0.1-py3-none-any.whl (7.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ipyplot) (1.19.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from ipyplot) (7.1.2)
# Requirement already satisfied: IPython in /usr/local/lib/python3.7/dist-packages (from ipyplot) (5.5.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (0.8.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (57.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (1.0.18)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (0.7.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (5.0.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython->ipyplot) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython->ipyplot) (0.2.5)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from traitlets>=4.2->IPython->ipyplot) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->IPython->ipyplot) (0.7.0)
# Installing collected packages: shortuuid, ipyplot
# Successfully installed ipyplot-1.1.0 shortuuid-1.0.1

# %%
import pandas as pd # Data analysis and manipultion tool
import numpy as np # Fundamental package for linear algebra and multidimensional arrays
import tensorflow as tf # Deep Learning Tool
import os # OS module in Python provides a way of using operating system dependent functionality
import cv2 # Library for image processing
from sklearn.model_selection import train_test_split # For splitting the data into train and validation set
from sklearn.metrics import f1_score, accuracy_score
import cv2
import ipyplot
from PIL  import Image
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
#         WARNING! Google Colab Environment detected!
#         You might encounter issues while running in Google Colab environment.
#         If images are not displaying properly please try setting `base_64` param to `True`.

# %%
train = pd.read_csv("/content/content/eye_gender_data/Training_set.csv")
test = pd.read_csv("/content/content/eye_gender_data/Testing_set.csv")

# %%
train.head()
# Out:
#       filename   label
# 0  Image_1.jpg    male
# 1  Image_2.jpg  female
# 2  Image_3.jpg  female
# 3  Image_4.jpg  female
# 4  Image_5.jpg    male

# %%
train_formated = train.copy()
train_formated['filename'] = "/content/content/eye_gender_data/train/" + train['filename']

# %%
train_formated.head()
# Out:
#                                             filename   label
# 0  /content/content/eye_gender_data/train/Image_1...    male
# 1  /content/content/eye_gender_data/train/Image_2...  female
# 2  /content/content/eye_gender_data/train/Image_3...  female
# 3  /content/content/eye_gender_data/train/Image_4...  female
# 4  /content/content/eye_gender_data/train/Image_5...    male

# %% [markdown]
# ## Prepare image and label lists

# %%
image_samples = train_formated['filename'].values.tolist()
image_labels = train_formated['label'].values.tolist()

# %%
import random
random.randint(1,100)
# Out:
# 48

# %%
image_array = []
image_label_array = []
for i in range(16):
  index = random.randint(1,100)
  img = Image.open(image_samples[index])
  image_array.append(img)
  image_label_array.append(image_labels[index])

# %% [markdown]
# ## Visualize The Images
#
# pro tip : https://www.linkedin.com/feed/update/urn:li:activity:6830366694209273856/

# %%
ipyplot.plot_images(image_array,image_label_array,img_width=200)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-QQ4sAJiD6fh3YyEDJLcijU {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-QQ4sAJiD6fh3YyEDJLcijU {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-QQ4sAJiD6fh3YyEDJLcijU {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-QQ4sAJiD6fh3YyEDJLcijU:checked ~ #ipyplot-html-viewer-textarea-QQ4sAJiD6fh3YyEDJLcijU {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-QQ4sAJiD6fh3YyEDJLcijU:checked + #ipyplot-html-viewer-label-QQ4sAJiD6fh3YyEDJLcijU:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-QQ4sAJiD6fh3YyEDJLcijU">
#         <label id="ipyplot-html-viewer-label-QQ4sAJiD6fh3YyEDJLcijU" for="ipyplot-html-viewer-toggle-QQ4sAJiD6fh3YyEDJLcijU">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-QQ4sAJiD6fh3YyEDJLcijU" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-KLVaowLSufsfWSj3H4pnf5 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5 {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5 {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5 img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-KLVaowLSufsfWSj3H4pnf5">
#     <div class="ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5">
#         <div id="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-BYgRXCs3X4EU4rnwhyAoyy" class="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">male</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-BYgRXCs3X4EU4rnwhyAoyy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5">
#         <div id="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-3EUGDwWYXqy5DFtCeqjKuQ" class="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">female</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-3EUGDwWYXqy5DFtCeqjKuQ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5">
#         <div id="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-PVyda9do2mvLqgMHo3rSez" class="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">female</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-PVyda9do2mvLqgMHo3rSez">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5">
#         <div id="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-GFBsFvij7jA4HW7BNfTEsE" class="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">male</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-GFBsFvij7jA4HW7BNfTEsE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5">
#         <div id="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-3GL8ULgTjpQmaRpzzVPa2n" class="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">female</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-3GL8ULgTjpQmaRpzzVPa2n">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5">
#         <div id="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-BG2j7XBt4f3k47GFCG8GCU" class="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">male</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-BG2j7XBt4f3k47GFCG8GCU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5">
#         <div id="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-gisEBMknAEmUUwQsmHmFTo" class="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">male</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-gisEBMknAEmUUwQsmHmFTo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5">
#         <div id="ipyplot-content-div-KLVaowLSufsfWSj3H
#         <style>
#         #ipyplot-imgs-container-div-KLVaowLSufsfWSj3H4pnf5 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5 {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5 {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5 img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-KLVaowLSufsfWSj3H4pnf5">
#     <div class="ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5">
#         <div id="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-BYgRXCs3X4EU4rnwhyAoyy" class="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">male</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-BYgRXCs3X4EU4rnwhyAoyy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5">
#         <div id="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-3EUGDwWYXqy5DFtCeqjKuQ" class="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">female</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-3EUGDwWYXqy5DFtCeqjKuQ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5">
#         <div id="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-PVyda9do2mvLqgMHo3rSez" class="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">female</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-PVyda9do2mvLqgMHo3rSez">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5">
#         <div id="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-GFBsFvij7jA4HW7BNfTEsE" class="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">male</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-GFBsFvij7jA4HW7BNfTEsE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5">
#         <div id="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-3GL8ULgTjpQmaRpzzVPa2n" class="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">female</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-3GL8ULgTjpQmaRpzzVPa2n">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5">
#         <div id="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-BG2j7XBt4f3k47GFCG8GCU" class="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">male</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-BG2j7XBt4f3k47GFCG8GCU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5">
#         <div id="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-gisEBMknAEmUUwQsmHmFTo" class="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">male</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-gisEBMknAEmUUwQsmHmFTo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5">
#         <div id="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-6pDEjACySP3DZwRJ7uBKJS" class="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">female</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-6pDEjACySP3DZwRJ7uBKJS">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5">
#         <div id="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-mNjKVeMk4wBacCwBZPTZwy" class="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">male</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-mNjKVeMk4wBacCwBZPTZwy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KLVaowLSufsfWSj3H4pnf5">
#         <div id="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5-6AJ4cNru3foEypEDaBTSUo" class="ipyplot-content-div-KLVaowLSufsfWSj3H4pnf5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">male</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KLVaowLSufsfWSj
